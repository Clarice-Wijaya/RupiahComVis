# %%
# !pip install ultralytics
# Out:
# ^C

# %%
# !pip list
# Out:
# Package            Version
# ------------------ -----------
# asttokens          2.4.1
# certifi            2024.8.30
# charset-normalizer 3.4.0
# colorama           0.4.6
# comm               0.2.2
# contourpy          1.3.1
# cycler             0.12.1
# debugpy            1.8.9
# decorator          5.1.1
# exceptiongroup     1.2.2
# executing          2.1.0
# filelock           3.16.1
# fonttools          4.55.0
# fsspec             2024.10.0
# idna               3.10
# importlib_metadata 8.5.0
# ipykernel          6.29.5
# ipython            8.29.0
# jedi               0.19.2
# Jinja2             3.1.4
# jupyter_client     8.6.3
# jupyter_core       5.7.2
# kiwisolver         1.4.7
# MarkupSafe         3.0.2
# matplotlib         3.9.2
# matplotlib-inline  0.1.7
# mpmath             1.3.0
# nest_asyncio       1.6.0
# networkx           3.4.2
# numpy              2.1.3
# opencv-python      4.10.0.84
# packaging          24.2
# pandas             2.2.3
# parso              0.8.4
# ...

# %%
# !nvidia-smi
# Out:
# Tue Nov 26 02:45:52 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.14                 Driver Version: 566.14         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4060      WDDM  |   00000000:01:00.0  On |                  N/A |
# | 30%   35C    P8             N/A /  115W |    1548MiB /   8188MiB |      3%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
# !pip list
# Out:
# Package            Version
# ------------------ -----------
# asttokens          2.4.1
# certifi            2024.8.30
# charset-normalizer 3.4.0
# colorama           0.4.6
# comm               0.2.2
# contourpy          1.3.1
# cycler             0.12.1
# debugpy            1.8.9
# decorator          5.1.1
# exceptiongroup     1.2.2
# executing          2.1.0
# filelock           3.16.1
# fonttools          4.55.0
# fsspec             2024.10.0
# idna               3.10
# importlib_metadata 8.5.0
# ipykernel          6.29.5
# ipython            8.29.0
# jedi               0.19.2
# Jinja2             3.1.4
# jupyter_client     8.6.3
# jupyter_core       5.7.2
# kiwisolver         1.4.7
# MarkupSafe         3.0.2
# matplotlib         3.9.2
# matplotlib-inline  0.1.7
# mpmath             1.3.0
# nest_asyncio       1.6.0
# networkx           3.4.2
# numpy              2.1.3
# opencv-python      4.10.0.84
# packaging          24.2
# pandas             2.2.3
# parso              0.8.4
# ...

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Tue_Feb_27_16:28:36_Pacific_Standard_Time_2024
# Cuda compilation tools, release 12.4, V12.4.99
# Build cuda_12.4.r12.4/compiler.33961263_0
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#   Using cached https://download.pytorch.org/whl/cu124/torchaudio-2.5.1%2Bcu124-cp310-cp310-win_amd64.whl (4.1 MB)
# ...
#      ---------------------------------------- 0.0/2.5 GB ? eta -:--:--
#      ---------------------------------------- 0.0/2.5 GB 4.2 MB/s eta 0:09:59
#      ---------------------------------------- 0.0/2.5 GB 4.2 MB/s eta 0:09:59
#      ---------------------------------------- 0.0/2.5 GB 4.2 MB/s eta 0:09:59
#      ---------------------------------------- 0.0/2.5 GB 4.2 MB/s eta 0:09:59
#      ---------------------------------------- 0.0/2.5 GB 1.7 MB/s eta 0:24:56
#      ---------------------------------------- 0.0/2.5 GB 1.6 MB/s eta 0:26:10
#      ---------------------------------------- 0.0/2.5 GB 1.4 MB/s eta 0:30:58
#      ---------------------------------------- 0.0/2.5 GB 1.4 MB/s eta 0:30:58
#      ---------------------------------------- 0.0/2.5 GB 1.2 MB/s eta 0:34:35
# ...

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolo11n-cls.yaml")  # build a new model from YAML
model = YOLO("yolo11l.pt")  # load a pretrained model (recommended for training)
# model = YOLO("yolo11n-cls.yaml").load("yolo11n-cls.pt")  # build from YAML and transfer weights

# Train the model
results = model.train(data="PROJECT-DATA-UANG-12/data.yaml", epochs=30, imgsz=640, batch=8, patience=3, device="cuda", lrf=1e-3, workers=8)
# Out:
# Ultralytics 8.3.55  Python-3.9.0 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# ...

# %%
from ultralytics import YOLO

# Load a model
# model = YOLO("yolo11n-cls.pt")  # load an official model
model = YOLO("runs/detect/train27/weights/best.pt")  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.top1  # top1 accuracy
metrics.top5  # top5 accuracy
# Out:
# Ultralytics 8.3.55  Python-3.9.0 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# YOLO11l summary (fused): 464 layers, 25,288,564 parameters, 0 gradients, 86.6 GFLOPs
# val: Scanning C:\Codes\Computer Vision\Project\datasets\PROJECT-DATA-UANG-11\valid\labels.cache... 547 images, 0 backgrounds, 0 corrupt: 100%|██████████| 547/547 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:15<00:00,  2.23it/s]
#                    all        547        547      0.996      0.997      0.991      0.969
#            1 RIBU ASLI         60         60      0.998          1      0.995      0.947
#           1 RIBU PALSU         29         29      0.998      0.966      0.969      0.949
#           10 RIBU ASLI         59         59      0.998          1      0.995      0.988
#          10 RIBU PALSU         33         33      0.968          1      0.977      0.897
# ...

# %%
# !yolo task=detect mode=predict model=runs/detect/train27/weights/last.pt conf=0.25 source=PROJECT-DATA-UANG-11/test/images save=True
# Out:
# Ultralytics 8.3.55 🚀 Python-3.9.21 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 4060, 8188MiB)
# YOLO11l summary (fused): 464 layers, 25,288,564 parameters, 0 gradients, 86.6 GFLOPs
#
# image 1/273 c:\Codes\Computer Vision\Project\PROJECT-DATA-UANG-11\test\images\WIN_20240626_16_38_51_Pro_mp4-0001_jpg.rf.82fa3cdd0822767fc16eaee6ed46bfcf.jpg: 640x640 1 100 RIBU ASLI, 16.0ms
# image 2/273 c:\Codes\Computer Vision\Project\PROJECT-DATA-UANG-11\test\images\WIN_20240626_16_38_51_Pro_mp4-0002_jpg.rf.0e1ff49991a436ffe9ca58f177c50ad4.jpg: 640x640 1 100 RIBU ASLI, 16.0ms
# image 3/273 c:\Codes\Computer Vision\Project\PROJECT-DATA-UANG-11\test\images\WIN_20240626_16_38_51_Pro_mp4-0009_jpg.rf.9a570e0fe082a3f7a1870888772ef5bc.jpg: 640x640 1 100 RIBU ASLI, 17.0ms
# image 4/273 c:\Codes\Computer Vision\Project\PROJECT-DATA-UANG-11\test\images\WIN_20240626_16_38_51_Pro_mp4-0032_jpg.rf.64ab46c0d0c1d2d337af893715c75664.jpg: 640x640 1 100 RIBU ASLI, 16.0ms
# ...
